# %%
#Grishav Bhardwaj
#19CSU118
#FS-A1


import getpass


class StatusException(Exception):
    pass

class UserIDException(Exception):
    pass

class PasswordException(Exception):
    pass


def afterLogin():
    count1=1
    print("Select an option: ")
    print("1. View Complaints")
    print("2. Register Complaint")
    print("3. Exit")
    option=input()
    if(option=="1"):
        file2 = open("C:\\Users\\Grishav\\Documents\\Python Scripts\\Crime Reporting System Project\\Admin\\complaints.txt","r")
        print("---------------------------------------------------------------------------------------------------------")
        print("|Type\t\t\t|Name Of Accuser\t|Status\t\t\t\t|Pin Code\t\t|")
        print(file2.read())
        print("---------------------------------------------------------------------------------------------------------")
        file2.close()
        afterLogin()
    elif(option=="2"):
        file2 = open("C:\\Users\\Grishav\\Documents\\Python Scripts\\Crime Reporting System Project\\Admin\\complaints.txt","r")
        for line in file2:
            count1=count1+1
        type1=input("Enter The Type Of Crime To Be Reported: ")
        name=input("Enter Your Name: ")
        status="Ongoing"
        pin="00"+str(count1)
        newline="|"+type1+"\t\t\t|"+name+"\t\t\t|"+status+"\t\t\t|"+pin+"\t\t\t|\n"
        file2 = open("C:\\Users\\Grishav\\Documents\\Python Scripts\\Crime Reporting System Project\\Admin\\complaints.txt","a")
        file2.write(newline)
        file2.close()
        print("\n~~~~~~~~~~Complaint Registered~~~~~~~~~~\n")
        print("Pincode Of Your Case Is:",pin,"\n")
        afterLogin()
    elif(option=="3"):
        exit()
    else:
        print("\nPlease select from the given options!\n")
        afterLogin()

        
def afterLogin1():
    flag4=True
    flag5=True
    print("Select an option: ")
    print("1. View Complaints")
    print("2. Update Complaints")
    print("3. Exit")
    option=input()
    if(option=="1"):
        file = open("C:\\Users\\Grishav\\Documents\\Python Scripts\\Crime Reporting System Project\\Admin\\complaints.txt","r")
        print("---------------------------------------------------------------------------------------------------------")
        print("|Type\t\t\t|Name Of Accuser\t|Status\t\t\t\t|Pin Code\t\t|")
        print(file.read())
        print("---------------------------------------------------------------------------------------------------------")
        file.close()
        afterLogin1()
    elif(option=="2"):
        file2 = open("C:\\Users\\Grishav\\Documents\\Python Scripts\\Crime Reporting System Project\\Admin\\complaints.txt","r")
        pin = input("Enter Pin Code Of Case To Update: ")
        lines=file2.readlines()
        for i in range(len(lines)):
            for line in lines[i].split("\t\t\t|"):
                if(line==pin):
                    flag4 = False
        while(flag4==False):
            for j in range(len(lines)):
                for line in lines[j].split("\t\t\t|"):
                    if(line==pin):
                        type1 = input("Enter New Type Of Case: ")
                        name1 = input("Enter New Name Of Accuser: ")
                        status1 = input("Enter New Status Of Case: ")
                        try:
                            if(status1!="Ongoing" and status1!="Completed"):
                                raise StatusException()
                            else:
                                flag5=False
                                newline = "|"+type1+"\t\t\t|"+name1+"\t\t\t|"+status1+"\t\t\t|"+pin+"\t\t\t|\n"
                                lines[j]=newline
                                flag4=True
                        except:
                            print("\nEither Enter 'Ongoing' Or 'Completed' As Status")
        if(flag5==False):
            print("\n~~~~~~~~~~File Updated Successfully~~~~~~~~~~\n")
        else:
            print("\nFile Could Not Be Updated!\n")
        file2 = open("C:\\Users\\Grishav\\Documents\\Python Scripts\\Crime Reporting System Project\\Admin\\complaints.txt","w")
        file2.writelines(lines)
        file2.close()
        afterLogin1()
    elif(option=="3"):
        exit()
    else:
        print("\nPlease select from the given options!\n")
        afterLogin1()


def register():
    flag1=True
    flag2=True
    while(flag1==True or flag2==True):
        flag1=True
        flag2=True
        file = open("C:\\Users\\Grishav\\Documents\\Python Scripts\\Crime Reporting System Project\\User\\id.txt","a")
        file1 = open("C:\\Users\\Grishav\\Documents\\Python Scripts\\Crime Reporting System Project\\User\\pass.txt","a")
        print("Enter new User ID: ")
        name0 = input()
        try:
            if(len(name0)<5):
                raise UserIDException()
            else:
                name1 = name0+"\n"
                file.write(name1)
                flag1=False
                print("Enter new Password: ")
                password0 = getpass.getpass()
                try:
                    if(len(password0)<5):
                        raise PasswordException()
                    else:
                        password1 = password0+"\n"
                        file1.write(password1)
                        flag2=False
                except:
                    print("\nPassword Should Be Longer Than 5 Letters!\n")
        except:
            print("\nUser ID Should Be Longer Than 5 Letters!\n")
        if(flag1==False and flag2==False):
            print("\n~~~~~~~~~~Registered Successfully~~~~~~~~~~\n")
        file.close()
        file1.close()

    
def login():
    file = open("C:\\Users\\Grishav\\Documents\\Python Scripts\\Crime Reporting System Project\\User\\id.txt","r")
    file1 = open("C:\\Users\\Grishav\\Documents\\Python Scripts\\Crime Reporting System Project\\User\\pass.txt","r")
    global flag3
    global count
    while(count<4 and flag3==False):
        count=count+1
        print("Enter User ID: ")
        name0 = input()
        print("Enter Password: ")
        password0 = getpass.getpass()
        name1 = name0+"\n"
        password1 = password0+"\n"
        for line in file:
            if(line==name1):
                global flag1 
                flag1 = True
        for line in file1:
            if(line==password1):
                global flag2 
                flag2 = True
        if(flag1==True and flag2 == True):
            flag3=True
        else:
            print("\nWrong User ID or Password, try again!\n")
        file.seek(0, 0)
        file1.seek(0, 0)
    if(flag1==True and flag2 == True):
        print("\n~~~~~~~~~~Logged in successfully~~~~~~~~~~\n")
        file.close()
        file1.close()
        afterLogin()
    else:
        print("\nToo many wrong attempts! Closing program...")
        file.close()
        file1.close()
        flag=False
    
        
def login1():
    file = open("C:\\Users\\Grishav\\Documents\\Python Scripts\\Crime Reporting System Project\\Admin\\id.txt","r")
    file1 = open("C:\\Users\\Grishav\\Documents\\Python Scripts\\Crime Reporting System Project\\Admin\\pass.txt","r")
    global flag3
    global count
    flag4 = True
    while(count<4 and flag3==False):
        count=count+1
        print("Enter User ID: ")
        name0 = input()
        print("Enter Password: ")
        password0 = getpass.getpass()
        name1 = name0+"\n"
        password1 = password0+"\n"
        for line in file:
            if(line==name1):
                global flag1 
                flag1 = True
        for line in file1:
            if(line==password1):
                global flag2 
                flag2 = True
        if(flag1==True and flag2 == True):
            flag3=True
        else:
            print("\nWrong User ID or Password, try again!\n")
        file.seek(0, 0)
        file1.seek(0, 0)
    if(flag1==True and flag2 == True):
        print("\n~~~~~~~~~~Logged in successfully~~~~~~~~~~\n")
        file.close()
        file1.close()
        afterLogin1()
    else:
        print("\nToo many wrong attempts! Closing program...")
        file.close()
        file1.close()
        global flag
        flag=False
      
    
def directAccess():
    flag4 = True
    pin=input("Enter The Pincode: ")
    file2 = open("C:\\Users\\Grishav\\Documents\\Python Scripts\\Crime Reporting System Project\\Admin\\complaints.txt","r")
    lines=file2.readlines()
    for i in range(len(lines)):
        for line in lines[i].split("\t\t\t|"):
            if(line==pin):
                flag4 = False
    if(flag4==False):
        for i in range(len(lines)):
            for line in lines[i].split("\t\t\t|"):
                if(line==pin):
                    print("---------------------------------------------------------------------------------------------------------")
                    print("|Type\t\t\t|Name Of Accuser\t|Status\t\t\t\t|Pin Code\t\t|")
                    print(lines[i])
                    print("---------------------------------------------------------------------------------------------------------")
    else:
        print("\nWrong Pincode Entered!\n")
    file2.close()
    
    
def role1():
    print("Select an option: ")
    print("1. Register")
    print("2. Login")
    print("3. Exit")
    option = input()
    if(option=="1"):
        register()
        role1()
    elif(option=="2"):
        login()
    elif(option=="3"):
        exit()
    else:
        print("\nPlease select from the given options!\n")
        role1()
       
    
def role2():
    print("Select an option: ")
    print("1. Login")
    print("2. Exit")
    option = input()
    if(option=="1"):
        login1()
    elif(option=="2"):
        exit()
    else:
        print("\nPlease select from the given options!\n")
        role2()

        
def exit():
    print("\n~~~~~~~~~~Program closed~~~~~~~~~~")
    global flag
    flag=False
    



print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
print("Crime Reporting System Project")
print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n")

global flag 
flag = True
global flag1
flag1= False
global flag2
flag2= False
global flag3
flag3= False
global count 
count = 0
while(flag):
    print("Select an option: ")
    print("1. Go Ahead As An User")
    print("2. Go Ahead As An Admin")
    print("3. Check The Status Of A Case By Pincode")
    print("4. Exit")
    role = input()
    if(role=="1"):
        role1()
    elif(role=="2"):
        role2()
    elif(role=="3"):
        directAccess()
    elif(role=="4"):
        exit()
    else:
        print("\nPlease select from the given options!\n")
# Out:
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Crime Reporting System Project
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Select an option:
# 1. Go Ahead As An User
# 2. Go Ahead As An Admin
# 3. Check The Status Of A Case By Pincode
# 4. Exit
